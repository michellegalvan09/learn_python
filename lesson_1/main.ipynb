# %% [markdown]
# # Lean Python
#
# Learning python the right way using Jupetior notebooks

# %%
print("helo world!!")
# Out:
# helo world!!

# %%
print("Im a super hero") # my secret identity is clue
# Out:
# Im a super hero

# %%
print("""
no,no me importa 
quien eres
porque me buscas?
""")
# Out:
# no,no me importa
# quien eres
# porque me buscas?

# %%
cosa="Nick"
print("me gusta el " + cosa  * 7 + " <3" *5 *8 )
# Out:
# me gusta el NickNickNickNickNickNickNick <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3 <3
